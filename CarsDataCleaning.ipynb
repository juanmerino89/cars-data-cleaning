# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import re
import os

# %% [markdown]
# # File Loading

# %%
folder = 'data_cars'
files = os.listdir(folder)

dfs = []

headers = ['URL','Car','Status','Price_1','Price_2','Mileage','Dealer_1','Dealer_2','Dealer_3']

for file in files:
    path = os.path.join(folder, file)
    
    df = pd.read_excel(path, names=headers)
    
    dfs.append(df)

Cars = pd.concat(dfs)

Cars = Cars.drop_duplicates(subset='URL')
Cars.dropna(subset=['Car'], inplace=True)
Cars
# Out:
#                                                      URL  \
# 1      https://www.cars.com/vehicledetail/5ee74d2b-dd...
# 2      https://www.cars.com/vehicledetail/460b9155-fa...
# 3      https://www.cars.com/vehicledetail/a0594120-25...
# 4      https://www.cars.com/vehicledetail/b185d19c-b4...
# 5      https://www.cars.com/vehicledetail/52bb1768-17...
# ...                                                  ...
# 10494  https://www.cars.com/vehicledetail/06665049-49...
# 10495  https://www.cars.com/vehicledetail/9e367454-56...
# 10496  https://www.cars.com/vehicledetail/d578331d-53...
# 10497  https://www.cars.com/vehicledetail/3b7dc7d4-60...
# 10498  https://www.cars.com/vehicledetail/928e7189-1c...
#
#                                                Car Status Price_1  Price_2  \
# 1      2023 Mazda CX-50 2.5 S Premium Plus Package    New   36703      NaN
# 2                              2023 Kia Sportage S    New   28990      NaN
# 3                        2024 Chevrolet Camaro 2LT    New   41425      NaN
# 4                        2023 Ford Bronco Badlands   Used     NaN  58900.0
# 5                           2021 Acura TLX Advance   Used     NaN  34499.0
# ...                                            ...    ...     ...      ...
# 10494       2023 Chevrolet Corvette Stingray w/3LT    New  122455      NaN
# 10495       2023 Chevrolet Corvette Stingray w/3LT    New  125930      NaN
# 10496                   2023 Jeep Wrangler Rubicon    New   53715      NaN
# 10497               2023 Jeep Wrangler Rubicon 392    New   91450      NaN
# 10498                          2023 Chrysler 300 S    New   52000      NaN
#
#                                                  Mileage  \
# 1            \n\n\n  $36,703\n\n      MSRP $38,635\n\n\n
# 2                                \n\n\n  $28,990\n\n\n\n
# 3            \n\n\n  $41,425\n\n      MSRP $41,425\n\n\n
# 4                                              1,551 mi.
# 5                                             30,384 mi.
# ...                                                  ...
# 10494                           \n\n\n  $122,455\n\n\n\n
# 10495                           \n\n\n  $125,930\n\n\n\n
# 10496  \n\n\n  $53,715\n\n      MSRP $58,715\n\n\n   ...
# 10497  \n\n\n  $91,450\n\n      MSRP $86,455\n\n\n   ...
# 10498  \n\n\n  $52,000\n\n      MSRP $53,000\n\n\n   ...
#
#                                  Dealer_1                          Dealer_2  \
# 1                                     NaN                               NaN
# 2                                     NaN                       Classic Kia
# 3                                     NaN        Classic Chevrolet Beaumont
# 4      Mike Smith Chrysler Dodge Jeep RAM                               NaN
# 5                       Mike Smith Nissan                               NaN
# ...                                   ...                               ...
# 10494                                 NaN                               NaN
# 10495                                 NaN                               NaN
# 10496                                 NaN  Stockton Dodge Chrysler Jeep RAM
# 10497                                 NaN  Stockton Dodge Chrysler Jeep RAM
# 10498                                 NaN  Stockton Dodge Chrysler Jeep RAM
#
#               Dealer_3
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# ...                ...
# 10494  Chase Chevrolet
# 10495  Chase Chevrolet
# 10496              NaN
# 10497              NaN
# 10498              NaN
#
# [18660 rows x 9 columns]

# %% [markdown]
# Let's navigate into the dataset:

# %% [markdown]
# # Data Cleaning

# %%
Cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18660 entries, 1 to 10498
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   URL       18660 non-null  object
#  1   Car       18660 non-null  object
#  2   Status    18660 non-null  object
#  3   Price_1   9427 non-null   object
#  4   Price_2   9233 non-null   object
#  5   Mileage   18660 non-null  object
#  6   Dealer_1  8942 non-null   object
#  7   Dealer_2  8603 non-null   object
#  8   Dealer_3  1082 non-null   object
# dtypes: object(9)
# memory usage: 1.4+ MB

# %%
Cars.describe()
# Out:
#                                                       URL  \
# count                                               18660
# unique                                              18660
# top     https://www.cars.com/vehicledetail/5ee74d2b-dd...
# freq                                                    1
#
#                         Car Status     Price_1  Price_2  \
# count                 18660  18660        9427   9233.0
# unique                 7086     30        7285   5921.0
# top     2023 Ford F-150 XLT    New  Not Priced  33995.0
# freq                     72   9427         386     26.0
#
#                            Mileage  Dealer_1            Dealer_2   Dealer_3
# count                        18660      8942                8603       1082
# unique                       17281      3087                3370        793
# top     \n\n\n      Not Priced\n\n  Auto Hub  Morgan City Toyota  Doral Kia
# freq                           163        64                  34          7

# %% [markdown]
# We need to get the next fields:
#
# - Brand
# - Model
# - Year
# - Status
# - Mileage
# - Dealer
# - Price
#
# Let's work on this!

# %% [markdown]
# ## Brand

# %% [markdown]
# In order to get the Brand field, I see two possible approaches:
#
# - Extract from the first words of Car field.
# - Use a dictionary.
#
# Personally I prefer the second one, since I suspect the Brand name isn't always in the same position, as well as we will find Brands with one, two, three words that gonna make difficult the task.

# %%
brands_df = pd.read_excel('master_data/brands.xlsx')

brands_df
# Out:
#                 keyword               brands
# 0                  Ford                 Ford
# 1             Chevrolet            Chevrolet
# 2                Toyota               Toyota
# 3                 Honda                Honda
# 4                Nissan               Nissan
# 5                  Jeep                 Jeep
# 6                Subaru               Subaru
# 7               Hyundai              Hyundai
# 8                   Kia                  Kia
# 9                 Dodge                Dodge
# 10                  GMC                  GMC
# 11                  BMW                  BMW
# 12             Mercedes             Mercedes
# 13                 Audi                 Audi
# 14           Volkswagen           Volkswagen
# 15                Lexus                Lexus
# 16             Cadillac             Cadillac
# 17             Chrysler             Chrysler
# 18                  Ram                  RAM
# 19                Buick                Buick
# 20                Tesla                Tesla
# 21                Acura                Acura
# 22             Infiniti             Infiniti
# 23                Mazda                Mazda
# 24              Lincoln              Lincoln
# 25           Land Rover           Land Rover
# 26               Jaguar               Jaguar
# 27                Volvo                Volvo
# 28              Porsche              Porsche
# 29                 Mini                 MINI
# 30           Alfa Romeo           Alfa Romeo
# 31              Genesis              Genesis
# 32           Mitsubishi           Mitsubishi
# 33                 Fiat                 FIAT
# 34             Maserati             Maserati
# 35                Royce          Rolls-Royce
# 36                Rolls          Rolls-Royce
# 37              Bentley              Bentley
# 38              Bugatti              Bugatti
# 39         Aston Martin         Aston Martin
# 40              Ferrari              Ferrari
# 41          Lamborghini          Lamborghini
# 42              McLaren              McLaren
# 43                Karma                Karma
# 44               Rivian               Rivian
# 45                Lucid                Lucid
# 46             Polestar             Polestar
# 47            Bollinger            Bollinger
# 48               Hummer               Hummer
# 49              Mercury              Mercury
# 50               Saturn               Saturn
# 51                Scion                Scion
# 52              Pontiac              Pontiac
# 53                Smart                Smart
# 54                Lotus                Lotus
# 55                 Saab                 Saab
# 56              Maybach              Maybach
# 57               Suzuki               Suzuki
# 58  International Scout  International Scout
# 59                  Geo                  Geo

# %%
brands_dict = brands_df.set_index('keyword')['brands'].to_dict()

def assign_profile(row):
    for col in ['Car']:
        cell_value = str(row[col])  # Convierte el valor a cadena de texto
        for keyword, brands in brands_dict.items():
            if keyword.lower() in cell_value.lower():
                return brands
    return 'Other'

Cars['Brand'] = Cars.apply(assign_profile, axis=1)

# %%
brands_counts = Cars['Brand'].value_counts()

print(brands_counts)
# Out:
# Ford                   2386
# Toyota                 1783
# Chevrolet              1720
# Jeep                   1108
# GMC                     941
# BMW                     893
# Mercedes                831
# Honda                   774
# Lexus                   692
# Kia                     682
# Audi                    602
# Mazda                   522
# RAM                     511
# Nissan                  494
# Hyundai                 429
# Volkswagen              408
# Cadillac                382
# Dodge                   365
# Subaru                  335
# Land Rover              328
# Acura                   319
# Volvo                   265
# Porsche                 247
# Lincoln                 241
# Infiniti                218
# Genesis                 207
# Buick                   154
# Jaguar                  115
# Tesla                   114
# Chrysler                103
# Mitsubishi               82
# MINI                     69
# Alfa Romeo               61
# Maserati                 57
# Bentley                  40
# Aston Martin             35
# Rolls-Royce              19
# McLaren                  16
# Polestar                 15
# Hummer                   13
# Pontiac                  12
# Lamborghini              11
# FIAT                     10
# Ferrari                  10
# Scion                    10
# Saturn                    9
# Rivian                    5
# Mercury                   4
# Lucid                     3
# Karma                     2
# Saab                      2
# Smart                     1
# Lotus                     1
# Maybach                   1
# Suzuki                    1
# International Scout       1
# Geo                       1
# Name: Brand, dtype: int64

# %%
other_cars = Cars[Cars['Brand'] == 'Other']['Car']

print(other_cars)
# Out:
# Series([], Name: Car, dtype: object)

# %% [markdown]
# Perfect!

# %% [markdown]
# ## Model

# %% [markdown]
# The approach is the same as the brand, creating and using a dictionary:

# %%
models_df = pd.read_excel('master_data/models.xlsx')

models_df
# Out:
#         keyword      model
# 0     Outlander  Outlander
# 1       Mustang    Mustang
# 2         F-150      F-150
# 3      Explorer   Explorer
# 4        Escape     Escape
# ..          ...        ...
# 739       924 S      924 S
# 740           2          2
# 741           1          1
# 742           3          3
# 743           6          6
#
# [744 rows x 2 columns]

# %%
models_dict = models_df.set_index('keyword')['model'].to_dict()

def assign_profile(row):
    for col in ['Car']:
        cell_value = str(row[col])  # Convierte el valor a cadena de texto
        for keyword, model in models_dict.items():
            if isinstance(keyword, str) and keyword.lower() in cell_value.lower():
                return model
    return 'Other'

Cars['Model'] = Cars.apply(assign_profile, axis=1)

# %%
models_counts = Cars['Model'].value_counts()

print(models_counts)
# Out:
# F-150            639
# Silverado        462
# Sierra           415
# Wrangler         409
# Mustang          371
#                 ...
# Alpina             1
# Silver Seraph      1
# Marquis            1
# C10                1
# 924 S              1
# Name: Model, Length: 500, dtype: int64

# %%
Cars[['Brand','Model','Price_1','Price_2','Mileage']]
# Out:
#            Brand     Model Price_1  Price_2  \
# 1          Mazda      CX-5   36703      NaN
# 2            Kia  Sportage   28990      NaN
# 3      Chevrolet    Camaro   41425      NaN
# 4           Ford    Bronco     NaN  58900.0
# 5          Acura       TLX     NaN  34499.0
# ...          ...       ...     ...      ...
# 10494  Chevrolet  Corvette  122455      NaN
# 10495  Chevrolet  Corvette  125930      NaN
# 10496       Jeep  Wrangler   53715      NaN
# 10497       Jeep  Wrangler   91450      NaN
# 10498   Chrysler       300   52000      NaN
#
#                                                  Mileage
# 1            \n\n\n  $36,703\n\n      MSRP $38,635\n\n\n
# 2                                \n\n\n  $28,990\n\n\n\n
# 3            \n\n\n  $41,425\n\n      MSRP $41,425\n\n\n
# 4                                              1,551 mi.
# 5                                             30,384 mi.
# ...                                                  ...
# 10494                           \n\n\n  $122,455\n\n\n\n
# 10495                           \n\n\n  $125,930\n\n\n\n
# 10496  \n\n\n  $53,715\n\n      MSRP $58,715\n\n\n   ...
# 10497  \n\n\n  $91,450\n\n      MSRP $86,455\n\n\n   ...
# 10498  \n\n\n  $52,000\n\n      MSRP $53,000\n\n\n   ...
#
# [18660 rows x 5 columns]

# %%
other_cars = Cars[Cars['Model'] == 'Other']['Car']

print(other_cars)
# Out:
# Series([], Name: Car, dtype: object)

# %% [markdown]
# Now looks nice!

# %% [markdown]
# ## Year

# %%
Cars['Year'] = Cars['Car'].str[:4]

# %%
Cars['Year'].value_counts()
# Out:
# 2023    7294
# 2024    2430
# 2022    1641
# 2021    1300
# 2020    1299
# 2019     924
# 2018     741
# 2017     601
# 2016     486
# 2015     418
# 2014     311
# 2013     256
# 2012     164
# 2011     164
# 2010      99
# 2008      90
# 2007      81
# 2006      65
# 2009      59
# 2004      47
# 2005      42
# 2003      26
# 2002      21
# 2001      19
# 1999      11
# 2000      11
# 1997       7
# 1998       6
# 1990       6
# 1995       5
# 1992       3
# 1993       3
# 1994       3
# 1979       2
# 1987       2
# 1989       2
# 1988       2
# 1970       2
# 1991       2
# 1996       2
# 1969       1
# 1973       1
# 1982       1
# 1971       1
# 1975       1
# 1977       1
# 1976       1
# 1972       1
# 1983       1
# 1978       1
# 1984       1
# 1985       1
# 1968       1
# Name: Year, dtype: int64

# %% [markdown]
# Perfect!

# %% [markdown]
# ## Status

# %% [markdown]
# To get the Status, we will transform the Certified ones into a single "Certified" Category:

# %%
Cars['Status'].value_counts()
# Out:
# New                        9427
# Used                       7971
# Toyota Certified            151
# Ford Certified              128
# Honda Certified              97
# Chevrolet Certified          85
# Mercedes-Benz Certified      82
# BMW Certified                72
# Porsche Certified            64
# Kia Certified                58
# Volvo Certified              54
# Audi Certified               50
# Volkswagen Certified         50
# GMC Certified                49
# Cadillac Certified           43
# Jeep Certified               41
# Acura Certified              39
# Nissan Certified             38
# INFINITI Certified           32
# Hyundai Certified            30
# Subaru Certified             25
# Lincoln Certified            22
# Dodge Certified              18
# RAM Certified                17
# Buick Certified               4
# Ferrari Certified             3
# Bentley Certified             3
# Chrysler Certified            3
# Rolls-Royce Certified         3
# Maserati Certified            1
# Name: Status, dtype: int64

# %%
Cars['Status'] = Cars['Status'].astype(str)
Cars['Status'] = Cars['Status'].apply(lambda x: 'Certified' if 'Certified' in x else x)

# %%
Cars['Status'].value_counts()
# Out:
# New          9427
# Used         7971
# Certified    1262
# Name: Status, dtype: int64

# %% [markdown]
# ## Mileage

# %% [markdown]
# We need to transform the Mileage column. First of all we need to delete ones that include the ' mi.' string, and then, for the rest we will delete the ' mi.' string:

# %%
def transform_mileage(mileage):
    if isinstance(mileage, str) and ' mi.' in mileage:
        # Elimina " mi." y convierte el valor a número (eliminando comas y espacios en blanco)
        return float(mileage.replace(' mi.', '').replace(',', '').strip())
    else:
        # Si no contiene " mi.", establece el valor como NaN
        return np.nan

# Aplica la función a la columna "Mileage"
Cars['Mileage'] = Cars['Mileage'].apply(transform_mileage)

# %%
Cars
# Out:
#                                                      URL  \
# 1      https://www.cars.com/vehicledetail/5ee74d2b-dd...
# 2      https://www.cars.com/vehicledetail/460b9155-fa...
# 3      https://www.cars.com/vehicledetail/a0594120-25...
# 4      https://www.cars.com/vehicledetail/b185d19c-b4...
# 5      https://www.cars.com/vehicledetail/52bb1768-17...
# ...                                                  ...
# 10494  https://www.cars.com/vehicledetail/06665049-49...
# 10495  https://www.cars.com/vehicledetail/9e367454-56...
# 10496  https://www.cars.com/vehicledetail/d578331d-53...
# 10497  https://www.cars.com/vehicledetail/3b7dc7d4-60...
# 10498  https://www.cars.com/vehicledetail/928e7189-1c...
#
#                                                Car Status Price_1  Price_2  \
# 1      2023 Mazda CX-50 2.5 S Premium Plus Package    New   36703      NaN
# 2                              2023 Kia Sportage S    New   28990      NaN
# 3                        2024 Chevrolet Camaro 2LT    New   41425      NaN
# 4                        2023 Ford Bronco Badlands   Used     NaN  58900.0
# 5                           2021 Acura TLX Advance   Used     NaN  34499.0
# ...                                            ...    ...     ...      ...
# 10494       2023 Chevrolet Corvette Stingray w/3LT    New  122455      NaN
# 10495       2023 Chevrolet Corvette Stingray w/3LT    New  125930      NaN
# 10496                   2023 Jeep Wrangler Rubicon    New   53715      NaN
# 10497               2023 Jeep Wrangler Rubicon 392    New   91450      NaN
# 10498                          2023 Chrysler 300 S    New   52000      NaN
#
#        Mileage                            Dealer_1  \
# 1          NaN                                 NaN
# 2          NaN                                 NaN
# 3          NaN                                 NaN
# 4       1551.0  Mike Smith Chrysler Dodge Jeep RAM
# 5      30384.0                   Mike Smith Nissan
# ...        ...                                 ...
# 10494      NaN                                 NaN
# 10495      NaN                                 NaN
# 10496      NaN                                 NaN
# 10497      NaN                                 NaN
# 10498      NaN                                 NaN
#
#                                Dealer_2         Dealer_3      Brand     Model  \
# 1                                   NaN              NaN      Mazda      CX-5
# 2                           Classic Kia              NaN        Kia  Sportage
# 3            Classic Chevrolet Beaumont              NaN  Chevrolet    Camaro
# 4                                   NaN              NaN       Ford    Bronco
# 5                                   NaN              NaN      Acura       TLX
# ...                                 ...              ...        ...       ...
# 10494                               NaN  Chase Chevrolet  Chevrolet  Corvette
# 10495                               NaN  Chase Chevrolet  Chevrolet  Corvette
# 10496  Stockton Dodge Chrysler Jeep RAM              NaN       Jeep  Wrangler
# 10497  Stockton Dodge Chrysler Jeep RAM              NaN       Jeep  Wrangler
# 10498  Stockton Dodge Chrysler Jeep RAM              NaN   Chrysler       300
#
#        Year
# 1      2023
# 2      2023
# 3      2024
# 4      2023
# 5      2021
# ...     ...
# 10494  2023
# 10495  2023
# 10496  2023
# 10497  2023
# 10498  2023
#
# [18660 rows x 12 columns]

# %% [markdown]
# ## Dealer

# %% [markdown]
# In order to get the Dealer we will combine the three Dealer columns, since just one of them has the right value, and the other ones has NaN:

# %%
Cars['Dealer'] = Cars['Dealer_1'].combine_first(Cars['Dealer_2']).combine_first(Cars['Dealer_3'])

# %%
Cars
# Out:
#                                                      URL  \
# 1      https://www.cars.com/vehicledetail/5ee74d2b-dd...
# 2      https://www.cars.com/vehicledetail/460b9155-fa...
# 3      https://www.cars.com/vehicledetail/a0594120-25...
# 4      https://www.cars.com/vehicledetail/b185d19c-b4...
# 5      https://www.cars.com/vehicledetail/52bb1768-17...
# ...                                                  ...
# 10494  https://www.cars.com/vehicledetail/06665049-49...
# 10495  https://www.cars.com/vehicledetail/9e367454-56...
# 10496  https://www.cars.com/vehicledetail/d578331d-53...
# 10497  https://www.cars.com/vehicledetail/3b7dc7d4-60...
# 10498  https://www.cars.com/vehicledetail/928e7189-1c...
#
#                                                Car Status Price_1  Price_2  \
# 1      2023 Mazda CX-50 2.5 S Premium Plus Package    New   36703      NaN
# 2                              2023 Kia Sportage S    New   28990      NaN
# 3                        2024 Chevrolet Camaro 2LT    New   41425      NaN
# 4                        2023 Ford Bronco Badlands   Used     NaN  58900.0
# 5                           2021 Acura TLX Advance   Used     NaN  34499.0
# ...                                            ...    ...     ...      ...
# 10494       2023 Chevrolet Corvette Stingray w/3LT    New  122455      NaN
# 10495       2023 Chevrolet Corvette Stingray w/3LT    New  125930      NaN
# 10496                   2023 Jeep Wrangler Rubicon    New   53715      NaN
# 10497               2023 Jeep Wrangler Rubicon 392    New   91450      NaN
# 10498                          2023 Chrysler 300 S    New   52000      NaN
#
#        Mileage                            Dealer_1  \
# 1          NaN                                 NaN
# 2          NaN                                 NaN
# 3          NaN                                 NaN
# 4       1551.0  Mike Smith Chrysler Dodge Jeep RAM
# 5      30384.0                   Mike Smith Nissan
# ...        ...                                 ...
# 10494      NaN                                 NaN
# 10495      NaN                                 NaN
# 10496      NaN                                 NaN
# 10497      NaN                                 NaN
# 10498      NaN                                 NaN
#
#                                Dealer_2         Dealer_3      Brand     Model  \
# 1                                   NaN              NaN      Mazda      CX-5
# 32                      2017 Mazda CX-5 Touring       Used         NaN
# 33                          2023 Honda Civic LX        New       25845
# 34         2017 Honda Accord EX w/Honda Sensing       Used         NaN
# 35                        2022 Ford Maverick XL        New  Not Priced
# 36                       2022 Ford Maverick XLT        New  Not Priced
# 37                    2021 Volkswagen Atlas SEL       Used         NaN
# 38              2023 Toyota 4Runner SR5 Premium        New       49521
# 39              2023 Toyota 4Runner SR5 Premium        New       50342
# 40               2023 Jeep Wagoneer L Series II        New       82365
# 41                           2023 GMC Yukon SLE        New       63280
# 42                           2023 GMC Yukon SLT        New       71530
# 43                           2023 GMC Yukon SLT        New       70490
# 45      2024 Mazda Mazda3 FWD w/Premium Package        New       32110
# 46                        2023 GMC Yukon Denali        New       91765
# 47                        2023 GMC Yukon XL AT4        New       78335
# 48                        2023 GMC Yukon Denali        New       83500
# 49                 2012 Toyota Sequoia Platinum       Used         NaN
# 50            2020 Lincoln Continental Standard       Used         NaN
# 51                2008 Mercury Grand Marquis GS       Used         NaN
# 52        2023 Lexus IS 500 F SPORT Performance       Used         NaN
#
#     Price_2   Mileage                            Dealer_1  \
# 1       NaN       NaN                                 NaN
# 2       NaN       NaN                                 NaN
# 3       NaN       NaN                                 NaN
# 4   58900.0    1551.0  Mike Smith Chrysler Dodge Jeep RAM
# 5   34499.0   30384.0                   Mike Smith Nissan
# 6   34000.0   13895.0              Volkswagen of Beaumont
# 7   56954.0   68506.0                     BMW of Beaumont
# 8       NaN       NaN                                 NaN
# 9       NaN       NaN                                 NaN
# 10      NaN       NaN                                 NaN
# 11      NaN       NaN                                 NaN
# 12      NaN       NaN                                 NaN
# 13      NaN       NaN                                 NaN
# 14      NaN       NaN                                 NaN
# 15      NaN       NaN                                 NaN
# 16      NaN       NaN                                 NaN
# 17  23589.0   29009.0          Volkswagen of Lake Charles
# 18      NaN       NaN                                 NaN
# 19      NaN       NaN                                 NaN
# 20  39895.0   22251.0                  Big Star Buick GMC
# 21  45995.0    7142.0                  Big Star Buick GMC
# 23      NaN       NaN                                 NaN
# 24      NaN       NaN                                 NaN
# 25      NaN       NaN                                 NaN
# 26      NaN       NaN                                 NaN
# 27      NaN       NaN                                 NaN
# 28      NaN       NaN                                 NaN
# 29  36990.0   33196.0                  Big Star Buick GMC
# 30      NaN       NaN                                 NaN
# 31      NaN       NaN                                 NaN
# 32  16995.0   97892.0                        Bacliff Auto
# 33      NaN       NaN                                 NaN
# 34  16141.0   95294.0               Sterling McCall Honda
# 35      NaN       NaN                                 NaN
# 36      NaN       NaN                                 NaN
# 37  33127.0   32298.0                        Tejas Toyota
# 38      NaN       NaN                                 NaN
# 39      NaN       NaN                                 NaN
# 40      NaN       NaN                                 NaN
# 41      NaN       NaN                                 NaN
# 42      NaN       NaN                                 NaN
# 43      NaN       NaN                                 NaN
# 45      NaN       NaN                                 NaN
# 46      NaN       NaN                                 NaN
# 47      NaN       NaN                                 NaN
# 48      NaN       NaN                                 NaN
# 49  22288.0  114355.0              Mac Haik Ford Pasadena
# 50  28788.0   39500.0              Mac Haik Ford Pasadena
# 51  13500.0   50564.0               Fall Creek Motor Cars
# 52  60995.0    1199.0    Sterling McCall Lexus Clear Lake
#
#                            Dealer_2                         Dealer_3  \
# 1                               NaN                              NaN
# 2                       Classic Kia                              NaN
# 3        Classic Chevrolet Beaumont                              NaN
# 4                               NaN                              NaN
# 5                               NaN                              NaN
# 6                               NaN                              NaN
# 7                               NaN                              NaN
# 8
# 18       Honda        Passport  2023                     Community Honda
# 19         GMC           Yukon  2023                  Big Star Buick GMC
# 20       Lexus              ES  2021                  Big Star Buick GMC
# 21         GMC          Sierra  2022                  Big Star Buick GMC
# 23       Mazda           CX-30  2023                                 NaN
# 24         GMC           Yukon  2023                  Big Star Buick GMC
# 25         GMC           Yukon  2023                  Big Star Buick GMC
# 26         GMC           Yukon  2023                  Big Star Buick GMC
# 27         GMC           Yukon  2023                  Big Star Buick GMC
# 28         GMC           Yukon  2023                  Big Star Buick GMC
# 29      Toyota          Tundra  2019                  Big Star Buick GMC
# 30    Cadillac             CT5  2023                  Ron Craft Cadillac
# 31       Buick         Envista  2024          Martin Chevrolet Buick GMC
# 32       Mazda            CX-5  2017                        Bacliff Auto
# 33       Honda           Civic  2023               Sterling McCall Honda
# 34       Honda          Accord  2017               Sterling McCall Honda
# 35        Ford        Maverick  2022                      Planet Ford 59
# 36        Ford        Maverick  2022                      Planet Ford 59
# 37  Volkswagen           Atlas  2021                        Tejas Toyota
# 38      Toyota         4Runner  2023                        Tejas Toyota
# 39      Toyota         4Runner  2023                        Tejas Toyota
# 40        Jeep        Wagoneer  2023       Texan Dodge Chrysler Jeep Ram
# 41         GMC           Yukon  2023                     Texan GMC Buick
# 42         GMC           Yukon  2023                     Texan GMC Buick
# 43         GMC           Yukon  2023                     Texan GMC Buick
# 45       Mazda          Mazda3  2024                                 NaN
# 46         GMC           Yukon  2023                     Texan GMC Buick
# 47         GMC           Yukon  2023                     Texan GMC Buick
# 48         GMC           Yukon  2023                     Texan GMC Buick
# 49      Toyota         Sequoia  2012              Mac Haik Ford Pasadena
# 50     Lincoln     Continental  2020              Mac Haik Ford Pasadena
# 51     Mercury         Marquis  2008               Fall Creek Motor Cars
# 52       Lexus              IS  2023    Sterling McCall Lexus Clear Lake
#
#        Price
# 1    36703.0
# 2    28990.0
# 3    41425.0
# 4    58900.0
# 5    34499.0
# 6    34000.0
# 7    56954.0
# 8    61715.0
# 9    37945.0
# 10   33495.0
# 11   63627.0
# 12   67998.0
# 13   48998.0
# 14   52105.0
# 15   76816.0
# 16       NaN
# 17   23589.0
# 18   47935.0
# 19   71125.0
# 20   39895.0
# 21   45995.0
# 23   30890.0
# 24   77345.0
# 25   99605.0
# 26   89925.0
# 27  100205.0
# 28   75600.0
# 29   36990.0
# 30   53805.0
# 31   31655.0
# 32   16995.0
# 33   25845.0
# 34   16141.0
# 35       NaN
# 36       NaN
# 37   33127.0
# 38   49521.0
# 39   50342.0
# 40   82365.0
# 41   63280.0
# 42   71530.0
# 43   70490.0
# 45   32110.0
# 46   91765.0
# 47   78335.0
# 48   83500.0
# 49   22288.0
# 50   28788.0
# 51   13500.0
# 52   60995.0

# %% [markdown]
# # Generating files

# %% [markdown]
# Now let's generate the files!

# %%
Cars_file = Cars[['Brand','Model','Year','Status','Mileage','Dealer','Price']]
Cars_file.to_excel('cars.xlsx', index=False)
Cars_file.to_csv('cars.csv', index=False, encoding="utf-16")
